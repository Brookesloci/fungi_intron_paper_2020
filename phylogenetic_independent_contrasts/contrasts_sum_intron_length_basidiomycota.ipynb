# %%
library(readxl)
library(phytools)
# library(paleotree)
library(caper)
library(bestNormalize)
# Out:
# Loading required package: ape
#
# Loading required package: maps
#
# Loading required package: MASS
#
# Loading required package: mvtnorm
#
#
# Attaching package: ‘bestNormalize’
#
#
# The following object is masked from ‘package:MASS’:
#
#     boxcox

# %%
t <- read.tree("fungi_115_timetree_basidiomycota.nwk")
nt <- t
# set zero-length branches to be 1/1000000 total tree length
# http://blog.phytools.org/2015/06/update-to-rerootingmethod-for-ancestral.html
nt$edge.length[nt$edge.length==0] <- max(nodeHeights(t))*1e-6

# %%
d <- read.csv('stat.txt', sep='\t')
head(d)
# Out:
#   species                  taxid
# 1 Eremothecium_gossypii    1034331
# 2 Saccharomyces_cerevisiae  559292
# 3 Thielavia_terrestris      578455
# 4 Verticillium_dahliae     1202531
# 5 Agaricus_bisporus         936046
# 6 Aspergillus_nidulans      227321
#   genome
# 1 Ashbya_gossypii_fdag1.ASM96883v1
# 2 Saccharomyces_cerevisiae.R64-1-1
# 3 Thielavia_terrestris_nrrl_8126.ASM22611v1
# 4 Verticillium_dahliaejr2.GCA_000400815.2
# 5 Agaricus_bisporus_var_bisporus_h97.Agabi_varbisH97_2
# 6 Aspergillus_nidulans.ASM1142v1
#   organism_name                       assembly_level  genome_size num_CDS
# 1 Eremothecium gossypii FDAG1         Complete Genome  9157154     4759
# 2 Saccharomyces cerevisiae S288C      Complete Genome 12157105     6619
# 3 Thielavia terrestris NRRL 8126      Complete Genome 36912256     9802
# 4 Verticillium dahliae JR2            Complete Genome 36150287    11424
# 5 Agaricus bisporus var. bisporus H97 Chromosome      30233745    10441
# 6 Aspergillus nidulans FGSC A4        Chromosome      29925798    10533
#   num_introns sum_CDS_length sum_intron_length intron_per_kb
# 1   270        7003446         28117           0.0385524
# 2   282        8801211        111916           0.0320410
# 3 17290       13641909       1958465           1.2674200
# 4 16261       15594541       1486506           1.0427400
# 5 50790       13351824       3487144           3.8039700
# 6 24460       15266724       2186566           1.6021800

# %%
# trying different transformations
# intron_per_kb
log_obj <- log10(d$intron_per_kb)
arcsinh_obj <- arcsinh_x(d$intron_per_kb)
boxcox_obj <- boxcox(d$intron_per_kb + 0.001)
yeojohnson_obj <- yeojohnson(d$intron_per_kb)
orderNorm_obj <- orderNorm(d$intron_per_kb)
par(mfrow = c(2,3))
MASS::truehist(d$intron_per_kb, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Warning message in orderNorm(d$intron_per_kb):
# “Ties in data, Normal distribution not guaranteed
# ”
# Plot with title “orderNorm”

# %%
# genome_size
log_obj <- log10(d$genome_size)
arcsinh_obj <- arcsinh_x(d$genome_size)
boxcox_obj <- boxcox(d$genome_size)
yeojohnson_obj <- yeojohnson(d$genome_size)
orderNorm_obj <- orderNorm(d$genome_size)
par(mfrow = c(2,3))
MASS::truehist(d$genome_size, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Warning message in optimize(yj_loglik, lower = lower, upper = upper, maximum = TRUE, :
# “NA/Inf replaced by maximum positive value”
# Plot with title “orderNorm”

# %%
# num_CDS
log_obj <- log10(d$num_CDS)
arcsinh_obj <- arcsinh_x(d$num_CDS)
boxcox_obj <- boxcox(d$num_CDS)
yeojohnson_obj <- yeojohnson(d$num_CDS)
orderNorm_obj <- orderNorm(d$num_CDS)
par(mfrow = c(2,3))
MASS::truehist(d$num_CDS, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Plot with title “orderNorm”

# %%
# num_introns
log_obj <- log10(d$num_introns + 1)
arcsinh_obj <- arcsinh_x(d$num_introns + 1)
boxcox_obj <- boxcox(d$num_introns + 1)
yeojohnson_obj <- yeojohnson(d$num_introns + 1)
orderNorm_obj <- orderNorm(d$num_introns + 1)
par(mfrow = c(2,3))
MASS::truehist(d$num_introns + 1, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Warning message in orderNorm(d$num_introns + 1):
# “Ties in data, Normal distribution not guaranteed
# ”
# Plot with title “orderNorm”

# %%
# sum_CDS_length
log_obj <- log10(d$sum_CDS_length)
arcsinh_obj <- arcsinh_x(d$sum_CDS_length)
boxcox_obj <- boxcox(d$sum_CDS_length)
yeojohnson_obj <- yeojohnson(d$sum_CDS_length)
orderNorm_obj <- orderNorm(d$sum_CDS_length)
par(mfrow = c(2,3))
MASS::truehist(d$sum_CDS_length, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Warning message in optimize(yj_loglik, lower = lower, upper = upper, maximum = TRUE, :
# “NA/Inf replaced by maximum positive value”
# Plot with title “orderNorm”

# %%
# sum_intron_length + 1
log_obj <- log10(d$sum_intron_length + 1)
arcsinh_obj <- arcsinh_x(d$sum_intron_length + 1)
boxcox_obj <- boxcox(d$sum_intron_length + 1)
yeojohnson_obj <- yeojohnson(d$sum_intron_length + 1)
orderNorm_obj <- orderNorm(d$sum_intron_length + 1)
par(mfrow = c(2,3))
MASS::truehist(d$sum_intron_length + 1, main = "No transformation", nbins = 12)
MASS::truehist(log_obj, main = "log10", nbins = 12)
MASS::truehist(arcsinh_obj$x.t, main = "Arcsinh", nbins = 12)
MASS::truehist(boxcox_obj$x.t, main = "Box Cox", nbins = 12)
MASS::truehist(yeojohnson_obj$x.t, main = "Yeo-Johnson", nbins = 12)
MASS::truehist(orderNorm_obj$x.t, main = "orderNorm", nbins = 12)
# Out:
# Warning message in orderNorm(d$sum_intron_length + 1):
# “Ties in data, Normal distribution not guaranteed
# ”
# Plot with title “orderNorm”

# %%
# boxcox transformation
d$bc_genome_size <- (boxcox(d$genome_size))$x.t
d$bc_intron_per_kb <- (boxcox(d$intron_per_kb + 0.001))$x.t
d$bc_num_CDS <- (boxcox(d$num_CDS))$x.t
d$bc_num_introns <- (boxcox(d$num_introns + 1))$x.t
d$bc_sum_CDS_length <- (boxcox(d$sum_CDS_length))$x.t
d$bc_sum_intron_length <- (boxcox(d$sum_intron_length + 1))$x.t

# %%
# phylogenetic independent contrasts
df <- comparative.data(nt, d, taxid)
bc <- crunch(bc_genome_size ~ bc_sum_CDS_length + bc_sum_intron_length, data=df)
crunchMod <- caic.robust(bc)
par(mfrow=c(2,2))
caic.diagnostics(crunchMod, outlier=1)
# Out:
# bc_sum_CDS_length :
#        Estimate  Std. Error t value Pr(>|t|)
# NV  -0.02488201  0.01442024 -1.7255  0.09508 .
# SD   0.00020158  0.00146391  0.1377  0.89143
# AGE -0.00625314  0.01062316 -0.5886  0.56066
#
# bc_sum_intron_length :
#      Estimate Std. Error t value Pr(>|t|)
# NV  0.0214840  0.0081303  2.6425 0.013130 *
# SD  0.0020863  0.0006466  3.2266 0.003100 **
# AGE 0.0187139  0.0042641  4.3887 0.000138 ***
#
# ---
# Signif. codes: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# plot without title
# plot without title

# %%
par(mfrow=c(1,1))
crunchTab <- caic.table(crunchMod)
plot(bc_genome_size ~ bc_sum_intron_length + bc_sum_CDS_length, crunchTab)
# Out:
# plot without title
# plot without title

# %%
pdf("contrasts_sum_intron_length_basidiomycota.pdf", width = 3.5, height = 4)
par(mfrow=c(1,1))
crunchTab <- caic.table(crunchMod)
plot(bc_genome_size ~ bc_sum_intron_length + bc_sum_CDS_length, crunchTab)
dev.off()
# Out:
# png
#   2

# %%
summary(crunchMod)
# Out:
# Call:
# lm(bc_genome_size ~ bc_sum_CDS_length + bc_sum_intron_length -
#     1, data = contrData)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.054905 -0.024711 -0.001556  0.022075  0.063813
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# bc_sum_CDS_length      0.2713     0.1116   2.431 0.021460 *
# bc_sum_intron_length   1.2626     0.2868   4.403 0.000133 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03324 on 29 degrees of freedom
# Multiple R-squared:  0.5188,	Adjusted R-squared:  0.4856
# F-statistic: 15.63 on 2 and 29 DF,  p-value: 2.474e-05

# %%
# correlation tests using contrasts
cor.test(crunchTab$bc_genome_size, crunchTab$bc_sum_intron_length, method='spearman')
cor.test(crunchTab$bc_genome_size, crunchTab$bc_sum_CDS_length, method='spearman')
# Out:
# 	Spearman's rank correlation rho
#
# data:  crunchTab$bc_genome_size and crunchTab$bc_sum_intron_length
# S = 1818, p-value = 0.0001819
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.6334677
# 	Spearman's rank correlation rho
#
# data:  crunchTab$bc_genome_size and crunchTab$bc_sum_CDS_length
# S = 3152, p-value = 0.04451
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.3645161

# %%
# correlation tests using the original data
cor.test(d$genome_size, d$bc_sum_intron_length, method='spearman')
cor.test(d$genome_size, d$bc_sum_CDS_length, method='spearman')
# Out:
# Warning message in cor.test.default(d$genome_size, d$bc_sum_intron_length, method = "spearman"):
# “Cannot compute exact p-value with ties”
# 	Spearman's rank correlation rho
#
# data:  d$genome_size and d$bc_sum_intron_length
# S = 86368, p-value = 1.144e-15
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.6592454
# 	Spearman's rank correlation rho
#
# data:  d$genome_size and d$bc_sum_CDS_length
# S = 83832, p-value < 2.2e-16
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.6692496

# %%
sessionInfo()
# Out:
# R version 4.0.3 (2020-10-10)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.10
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=en_NZ.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_NZ.UTF-8        LC_COLLATE=en_NZ.UTF-8
#  [5] LC_MONETARY=en_NZ.UTF-8    LC_MESSAGES=en_NZ.UTF-8
#  [7] LC_PAPER=en_NZ.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_NZ.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] bestNormalize_1.6.1 caper_1.0.1         mvtnorm_1.1-1
# [4] MASS_7.3-53         phytools_0.7-70     maps_3.3.0
# [7] ape_5.4-1           readxl_1.3.1
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.5              lubridate_1.7.9         lattice_0.20-41
#  [4] class_7.3-17            gtools_3.8.2            digest_0.6.25
#  [7] ipred_0.9-9             foreach_1.5.0           IRdisplay_0.7.0
# [10] R6_2.4.1                cellranger_1.1.0        repr_1.1.0
# [13] evaluate_0.14           coda_0.19-3             pillar_1.4.6
# [16] rlang_0.4.7             uuid_0.1-4              phangorn_2.5.5
# [19] rpart_4.1-15            Matrix_1.2-18           combinat_0.0-8
# [22] splines_4.0.3           gower_0.2.2             igraph_1.2.6
# [25] compiler_4.0.3          numDeriv_2016.8-1.1     pkgconfig_2.0.3
# [28] base64enc_0.1-3         mnormt_2.0.2            tmvnsim_1.0-2
# [31] htmltools_0.5.0         nnet_7.3-14             tidyselect_1.1.0
# [34] prodlim_2019.11.13      tibble_3.0.3            expm_0.999-5
# [37] quadprog_1.5-8          codetools_0.2-16        withr_2.2.0
# [40] crayon_1.3.4            dplyr_1.0.2             recipes_0.1.13
# [43] grid_4.0.3              nlme_3.1-149            jsonlite_1.7.1
# [46] lifecycle_0.2.0         magrittr_1.5            doRNG_1.8.2
# [49] scatterplot3d_0.3-41    doParallel_1.0.15       timeDate_3043.102
# [52] ellipsis_0.3.1          vctrs_0.3.4             generics_0.0.2
# [55] nortest_1.0-4           fastmatch_1.1-0         IRkernel_1.1.1
# [58] lava_1.6.7              iterators_1.0.12        tools_4.0.3
# [61] glue_1.4.2              purrr_0.3.4             rngtools_1.5
# [64] plotrix_3.7-8           parallel_4.0.3          survival_3.2-7
# [67] pbdZMQ_0.3-3            clusterGeneration_1.3.4
